# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow import keras
from keras import layers
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
import string
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL
import random
import time
from pathlib import Path

import re
from IPython import display
import cv2

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Preprocess text

# %%
dictionary_path = './2024-datalab-cup3-reverse-image-caption/dictionary'
vocab = np.load(dictionary_path + '/vocab.npy')
print('there are {} vocabularies in total'.format(len(vocab)))

word2Id_dict = dict(np.load(dictionary_path + '/word2Id.npy'))
id2word_dict = dict(np.load(dictionary_path + '/id2Word.npy'))
print('Word to id mapping, for example: %s -> %s' % ('flower', word2Id_dict['flower']))
print('Id to word mapping, for example: %s -> %s' % ('1', id2word_dict['1']))
print('Tokens: <PAD>: %s; <RARE>: %s' % (word2Id_dict['<PAD>'], word2Id_dict['<RARE>']))
# Out:
# there are 5427 vocabularies in total
# Word to id mapping, for example: flower -> 1
# Id to word mapping, for example: 1 -> flower
# Tokens: <PAD>: 5427; <RARE>: 5428

# %%
def sent2IdList(line, MAX_SEQ_LENGTH=20):
    MAX_SEQ_LIMIT = MAX_SEQ_LENGTH
    padding = 0
    
    # data preprocessing, remove all puntuation in the texts
    prep_line = re.sub('[%s]' % re.escape(string.punctuation), ' ', line.rstrip())
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('-', ' ')
    prep_line = prep_line.replace('  ', ' ')
    prep_line = prep_line.replace('.', '')
    tokens = prep_line.split(' ')
    tokens = [
        tokens[i] for i in range(len(tokens))
        if tokens[i] != ' ' and tokens[i] != ''
    ]
    l = len(tokens)
    padding = MAX_SEQ_LIMIT - l
    
    # make sure length of each text is equal to MAX_SEQ_LENGTH, and replace the less common word with <RARE> token
    for i in range(padding):
        tokens.append('<PAD>')
    line = [
        word2Id_dict[tokens[k]]
        if tokens[k] in word2Id_dict else word2Id_dict['<RARE>']
        for k in range(len(tokens))
    ]

    return line

text = "the flower shown has yellow anther red pistil and bright red petals."
print(text)
print(sent2IdList(text))
# Out:
# the flower shown has yellow anther red pistil and bright red petals.
# ['9', '1', '82', '5', '11', '70', '20', '31', '3', '29', '20', '2', '5427', '5427', '5427', '5427', '5427', '5427', '5427', '5427']

# %% [markdown]
# ## Dataset

# %%
data_path = './2024-datalab-cup3-reverse-image-caption/dataset'
df = pd.read_pickle(data_path + '/text2ImgData.pkl')
num_training_sample = len(df)
n_images_train = num_training_sample
print('There are %d image in training data' % (n_images_train))
# Out:
# There are 7370 image in training data

# %%
df.head(5)
# Out:
#                                                Captions  \
# ID
# 6734  [[9, 2, 17, 9, 1, 6, 14, 13, 18, 3, 41, 8, 11,...
# 6736  [[4, 1, 5, 12, 2, 3, 11, 31, 28, 68, 106, 132,...
# 6737  [[9, 2, 27, 4, 1, 6, 14, 7, 12, 19, 5427, 5427...
# 6738  [[9, 1, 5, 8, 54, 16, 38, 7, 12, 116, 325, 3, ...
# 6739  [[4, 12, 1, 5, 29, 11, 19, 7, 26, 70, 5427, 54...
#
#                          ImagePath
# ID
# 6734  ./102flowers/image_06734.jpg
# 6736  ./102flowers/image_06736.jpg
# 6737  ./102flowers/image_06737.jpg
# 6738  ./102flowers/image_06738.jpg
# 6739  ./102flowers/image_06739.jpg

# %% [markdown]
# ## Create dataset by dataset api

# %%
# in this competition, you have to generate image in size 64x64x3
IMAGE_HEIGHT = 64
IMAGE_WIDTH = 64
IMAGE_CHANNEL = 3

def training_data_generator(text_embeddings, image_path):
    # Load the image according to the image path
    img = tf.io.read_file(image_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, size=[IMAGE_HEIGHT, IMAGE_WIDTH])
    img.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNEL])
    text_embeddings = tf.cast(text_embeddings, tf.float32)
    return img, text_embeddings


def dataset_generator(filenames, batch_size, data_generator):
    # Load the training data into two lists: image paths and captions
    df = pd.read_pickle(filenames)
    all_image_paths = []
    all_text_embeddings = []

    # Expand each image path to match the number of captions
    for i in range(len(df)):
        image_path = df[i][0]
        # text embeddings is a array with shape (512,)
        text_embeddings = df[i][1]
        all_image_paths.append(image_path)
        all_text_embeddings.append(text_embeddings)

    # Convert to NumPy arrays
    all_text_embeddings = np.asarray(all_text_embeddings)  # Store captions as strings
    all_image_paths = np.asarray(all_image_paths)
    
    # Ensure alignment between captions and images
    assert len(all_text_embeddings) == len(all_image_paths)
    
    # Create a TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices((all_text_embeddings, all_image_paths))
    dataset = dataset.map(data_generator, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(len(all_text_embeddings)).batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
BATCH_SIZE = 32
dataset = dataset_generator('./2024-datalab-cup3-reverse-image-caption/dataset/image_text_pairs.pkl', BATCH_SIZE, training_data_generator)

# %%
# iter the next data in the dataset
data = next(iter(dataset))
print('Image batch shape:', data[0].shape)
print('Caption batch shape:', data[1].shape)

# %% [markdown]
# ## StackGAN

# %% [markdown]
# ### KL divergence

# %%
from keras import backend as K
def KL_loss(y_true, y_pred):
  mean = y_pred[:, :128]
  logsigma = y_pred[:, 128:]
  loss = -logsigma + 0.5*(-1 + K.exp(2.0*logsigma) + K.square(mean))
  loss = K.mean(loss)
  return loss

# %% [markdown]
# ### stage 1 GAN

# %%
class ConditioningAugmentation(tf.keras.Model):
  def __init__(self):
    super(ConditioningAugmentation, self).__init__()
    self.dense = tf.keras.layers.Dense(units = 256)

  def call(self, E):
    X = self.dense(E)
    phi = tf.nn.leaky_relu(X)
    mean = phi[:, :128]
    std = K.exp(phi[:, 128:])
    epsilon = K.random_normal(shape = K.constant((mean.shape[1], ), dtype = 'int32'))
    C = mean + epsilon*std
    return C, phi

# %%
class EmbeddingCompressor(tf.keras.Model):
  def __init__(self):
    super(EmbeddingCompressor, self).__init__()
    self.dense = tf.keras.layers.Dense(units = 128)

  def call(self, E):
    X = self.dense(E)
    return tf.nn.relu(X)

# %%
class Stage1Generator(tf.keras.Model):
    def __init__(self):
        super(Stage1Generator, self).__init__()
        self.canet = ConditioningAugmentation()
        self.concat = tf.keras.layers.Concatenate(axis=1)
        self.dense = tf.keras.layers.Dense(units=128 * 8 * 4 * 4, kernel_initializer=tf.random_normal_initializer(stddev=0.02))
        self.reshape = tf.keras.layers.Reshape(target_shape=(4, 4, 128 * 8), input_shape=(128 * 8 * 4 * 4,))
        self.batchnorm1 = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99)
        self.deconv1 = tf.keras.layers.Conv2DTranspose(filters=512, kernel_size=4, strides=(2, 2), padding="same", kernel_initializer=tf.random_normal_initializer(stddev=0.02))
        self.batchnorm2 = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99)
        self.deconv2 = tf.keras.layers.Conv2DTranspose(filters=256, kernel_size=4, strides=(2, 2), padding="same", kernel_initializer=tf.random_normal_initializer(stddev=0.02))
        self.batchnorm3 = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99)
        self.deconv3 = tf.keras.layers.Conv2DTranspose(filters=128, kernel_size=4, strides=(2, 2), padding="same", kernel_initializer=tf.random_normal_initializer(stddev=0.02))
        self.batchnorm4 = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99)
        self.deconv4 = tf.keras.layers.Conv2DTranspose(filters=3, kernel_size=4, strides=(2, 2), padding="same", kernel_initializer=tf.random_normal_initializer(stddev=0.02))

    def call(self, inputs):
        E, Z = inputs
        C, phi = self.canet(E)

        gen_input = self.concat([C, Z])
        
        X = self.dense(gen_input)
        X = self.reshape(X)
        X = self.batchnorm1(X)
        X = tf.nn.relu(X)

        X = self.deconv1(X)
        X = self.batchnorm2(X)
        X = tf.nn.relu(X)

        X = self.deconv2(X)
        X = self.batchnorm3(X)
        X = tf.nn.relu(X)

        X = self.deconv3(X)
        X = self.batchnorm4(X)
        X = tf.nn.relu(X)

        X = self.deconv4(X)
        return tf.nn.tanh(X), phi

# %%
class Stage1Discriminator(tf.keras.Model):
  def __init__(self):
    super(Stage1Discriminator, self).__init__()
    self.conv1 = tf.keras.layers.Conv2D(filters = 64, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.conv2 = tf.keras.layers.Conv2D(filters = 128, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm1 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv3 = tf.keras.layers.Conv2D(filters = 256, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm2 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv4 = tf.keras.layers.Conv2D(filters = 512, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm3 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.embed = EmbeddingCompressor()
    self.reshape = tf.keras.layers.Reshape(target_shape = (1, 1, 128))
    self.concat = tf.keras.layers.Concatenate()
    self.conv5 = tf.keras.layers.Conv2D(filters = 64*8, kernel_size = 1, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm4 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv6 = tf.keras.layers.Conv2D(filters = 1, kernel_size = 4, strides = 1, padding = "valid", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))

  def call(self, inputs):
    I, E = inputs
    X = self.conv1(I)
    X = tf.nn.leaky_relu(X)

    X = self.conv2(X)
    X = self.batchnorm1(X)
    X = tf.nn.leaky_relu(X)

    X = self.conv3(X)
    X = self.batchnorm2(X)
    X = tf.nn.leaky_relu(X)

    X = self.conv4(X)
    X = self.batchnorm3(X)
    X = tf.nn.leaky_relu(X)

    T = self.embed(E)
    T = self.reshape(T)
    T = tf.tile(T, (1, 4, 4, 1))
    merged_input = self.concat([X, T])

    Y = self.conv5(merged_input)
    Y = self.batchnorm4(Y)
    Y = tf.nn.leaky_relu(Y)

    Y = self.conv6(Y)
    return tf.squeeze(Y)

# %%
class Stage1Model(tf.keras.Model):
  def __init__(self):
    super(Stage1Model, self).__init__()
    self.stage1_generator = Stage1Generator()
    self.stage1_discriminator = Stage1Discriminator()

  def train(self, train_ds, batch_size = 32, num_epochs = 600, z_dim = 100, c_dim = 128, stage1_generator_lr = 0.0004, stage1_discriminator_lr = 0.0004):
    generator_optimizer = tf.keras.optimizers.Adam(lr = stage1_generator_lr, beta_1 = 0.5, beta_2 = 0.999)
    discriminator_optimizer = tf.keras.optimizers.Adam(lr = stage1_discriminator_lr, beta_1 = 0.5, beta_2 = 0.999)
    
    for epoch in range(num_epochs):
      print("Epoch %d/%d:\n ["%(epoch + 1, num_epochs), end = "")
      start_time = time.time()
      if epoch % 100 == 0:
        K.set_value(generator_optimizer.learning_rate, generator_optimizer.learning_rate / 2)
        K.set_value(discriminator_optimizer.learning_rate, discriminator_optimizer.learning_rate / 2)
    
      generator_loss_log = []
      discriminator_loss_log = []
      steps_per_epoch = 125
      batch_iter = iter(train_ds)
      for i in range(steps_per_epoch):
        if i % 5 == 0:
          print("=", end = "")
        image_batch, embedding_batch = next(batch_iter)
        z_noise = tf.random.normal((batch_size, z_dim))

        mismatched_images = tf.roll(image_batch, shift = 1, axis = 0)

        real_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.9, maxval = 1.0)
        fake_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.0, maxval = 0.1)
        mismatched_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.0, maxval = 0.1)

        with tf.GradientTape() as generator_tape, tf.GradientTape() as discriminator_tape:
          fake_images, phi = self.stage1_generator([embedding_batch, z_noise])
          
          real_logits = self.stage1_discriminator([image_batch, embedding_batch])
          fake_logits = self.stage1_discriminator([fake_images, embedding_batch])
          mismatched_logits = self.stage1_discriminator([mismatched_images, embedding_batch])
          
          l_sup = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(real_labels, fake_logits))
          l_klreg = KL_loss(tf.random.normal((phi.shape[0], phi.shape[1])), phi)
          generator_loss = l_sup + 2.0*l_klreg
          
          l_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(real_labels, real_logits))
          l_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(fake_labels, fake_logits))
          l_mismatched = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(mismatched_labels, mismatched_logits))
          discriminator_loss = 0.5*tf.add(l_real, 0.5*tf.add(l_fake, l_mismatched))
        
        generator_gradients = generator_tape.gradient(generator_loss, self.stage1_generator.trainable_variables)
        discriminator_gradients = discriminator_tape.gradient(discriminator_loss, self.stage1_discriminator.trainable_variables)
        
        generator_optimizer.apply_gradients(zip(generator_gradients, self.stage1_generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(discriminator_gradients, self.stage1_discriminator.trainable_variables))
        
        generator_loss_log.append(generator_loss)
        discriminator_loss_log.append(discriminator_loss)

      end_time = time.time()

      if epoch % 1 == 0:
        epoch_time = end_time - start_time
        template = "] - generator_loss: {:.4f} - discriminator_loss: {:.4f} - epoch_time: {:.2f} s"
        print(template.format(tf.reduce_mean(generator_loss_log), tf.reduce_mean(discriminator_loss_log), epoch_time))

      if (epoch + 1) % 10 == 0 or epoch == num_epochs - 1:
        save_path = "./Text to Image/lr_results/epoch_" + str(epoch + 1)
        temp_embeddings = None
        for _, embeddings in train_ds:
          temp_embeddings = embeddings.numpy()
          break
        if os.path.exists(save_path) == False:
          os.makedirs(save_path)
        temp_batch_size = 10
        temp_z_noise = tf.random.normal((temp_batch_size, z_dim))
        temp_embedding_batch = temp_embeddings[0:temp_batch_size]
        fake_images, _ = self.stage1_generator([temp_embedding_batch, temp_z_noise])
        for i, image in enumerate(fake_images):
          image = 127.5*image + 127.5
          image = image.numpy().astype('uint8')
          cv2.imwrite(save_path + "/gen_%d.png"%(i), image)
      
        self.stage1_generator.save_weights("./Text to Image/lr_model_checkpoints/stage1_generator_" + str(epoch + 1) + ".ckpt")
        self.stage1_discriminator.save_weights("./Text to Image/lr_model_checkpoints/stage1_discriminator_" + str(epoch + 1) + ".ckpt")

    def generate_image(self, embedding):
      self.stage1_generator.compile(loss = "mse", optimizer = "adam")
      self.stage1_generator.load_weights("./Text to Image/lr_model_checkpoints/stage1_generator_600.ckpt").expect_partial()
      z_noise = tf.random.normal((batch_size, z_dim))
      generated_image = self.stage1_generator([embedding, z_noise])
      return generated_image

# %%
model = Stage1Model()
model.train(dataset)
# Out:
# Epoch 1/600:
#  [=Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# =Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# Concatenated input shape: (32, 228)
# Dense layer output shape: (32, 16384)
# Reshaped output shape: (32, 4, 4, 1024)
# After deconv1: (32, 8, 8, 512)
# After deconv2: (32, 16, 16, 256)
# After deconv3: (32, 32, 32, 128)
# ] - generator_loss: 0.9393 - discriminator_loss: 0.6653 - epoch_time: 201.32 s
# Epoch 2/600:
#  [=

# %% [markdown]
# ### stage 2 GAN

# %%
class ResidualBlock(tf.keras.layers.Layer):
  def __init__(self):
    super(ResidualBlock, self).__init__()
    self.conv1 = tf.keras.layers.Conv2D(filters = 128*4, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm1 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv2 = tf.keras.layers.Conv2D(filters = 128*4, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm2 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)

    def call(self, I):
      X = self.conv1(I)
      X = self.batchnorm1(X)
      X = tf.nn.relu(X)

      X = self.conv2(X)
      X = self.batchnorm2(X)
      X = tf.nn.relu(X)
      X = tf.keras.layers.Add()([X, I])
      X = tf.nn.relu(X)
      return X

# %%
class Stage2Generator(tf.keras.Model):
  def __init__(self):
    super(Stage2Generator, self).__init__()
    self.canet = ConditioningAugmentation()
    self.conv1 = tf.keras.layers.Conv2D(128, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.conv2 = tf.keras.layers.Conv2D(256, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm1 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv3 = tf.keras.layers.Conv2D(512, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm2 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv4 = tf.keras.layers.Conv2D(512, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm3 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.resblock1 = ResidualBlock()
    self.resblock2 = ResidualBlock()
    self.resblock3 = ResidualBlock()
    self.resblock4 = ResidualBlock()
    self.upsamp1 = tf.keras.layers.UpSampling2D(size = (2, 2))
    self.conv5 = tf.keras.layers.Conv2D(256, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm4 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.upsamp2 = tf.keras.layers.UpSampling2D(size = (2, 2))
    self.conv6 = tf.keras.layers.Conv2D(filters = 128, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm5 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.upsamp3 = tf.keras.layers.UpSampling2D(size = (2, 2))
    self.conv7 = tf.keras.layers.Conv2D(filters = 64, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm6 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.upsamp4 = tf.keras.layers.UpSampling2D(size = (2, 2))
    self.conv8 = tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm7 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv9 = tf.keras.layers.Conv2D(filters = 3, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
  
  def call(self, inputs):
    E, I = inputs
    C, phi = self.canet(E)

    X = self.conv1(I)
    X = tf.nn.relu(X)
    
    X = self.conv2(X)
    X = self.batchnorm1(X)
    X = tf.nn.relu(X)

    X = self.conv3(X)
    X = self.batchnorm2(X)
    X = tf.nn.relu(X)

    C = K.expand_dims(C, axis = 1)
    C = K.expand_dims(C, axis = 1)
    C = K.tile(C, [1, 16, 16, 1])
    J = K.concatenate([C, X], axis = 3)

    X = self.conv4(X)
    X = self.batchnorm3(X)
    X = tf.nn.relu(X)

    X = self.resblock1(X)
    X = self.resblock2(X)
    X = self.resblock3(X)
    X = self.resblock4(X)

    X = self.upsamp1(X)
    X = self.conv5(X)
    X = self.batchnorm4(X)
    X = tf.nn.relu(X)
    
    X = self.upsamp2(X)
    X = self.conv6(X)
    X = self.batchnorm5(X)
    X = tf.nn.relu(X)
    
    X = self.upsamp3(X)
    X = self.conv7(X)
    X = self.batchnorm6(X)
    X = tf.nn.relu(X)
    
    X = self.upsamp4(X)
    X = self.conv8(X)
    X = self.batchnorm7(X)
    X = tf.nn.relu(X)
    
    X = self.conv9(X)
    return tf.nn.tanh(X), phi

# %%
class Stage2Discriminator(tf.keras.Model):
  def __init__(self):
    super(Stage2Discriminator, self).__init__()
    self.embed = EmbeddingCompressor()
    self.reshape = tf.keras.layers.Reshape(target_shape = (1, 1, 128))
    self.conv1 = tf.keras.layers.Conv2D(filters = 64, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.conv2 = tf.keras.layers.Conv2D(filters = 128, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm1 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv3 = tf.keras.layers.Conv2D(filters = 256, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm2 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv4 = tf.keras.layers.Conv2D(filters = 512, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm3 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv5 = tf.keras.layers.Conv2D(filters = 1024, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm4 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv6 = tf.keras.layers.Conv2D(filters = 2048, kernel_size = 4, strides = 2, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm5 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv7 = tf.keras.layers.Conv2D(filters = 1024, kernel_size = 1, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm6 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv8 = tf.keras.layers.Conv2D(filters = 512, kernel_size = 1, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm7 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv9 = tf.keras.layers.Conv2D(filters = 128, kernel_size = 1, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm8 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv10 = tf.keras.layers.Conv2D(filters = 128, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm9 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv11 = tf.keras.layers.Conv2D(filters = 512, kernel_size = 3, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm10 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv12 = tf.keras.layers.Conv2D(filters = 64*8, kernel_size = 1, strides = 1, padding = "same", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))
    self.batchnorm11 = tf.keras.layers.BatchNormalization(axis = -1, momentum = 0.99)
    self.conv13 = tf.keras.layers.Conv2D(filters = 1, kernel_size = 4, strides = 1, padding = "valid", kernel_initializer = tf.keras.initializers.TruncatedNormal(stddev = 0.02))

  def call(self, inputs):
    I, E = inputs
    T = self.embed(E)
    T = self.reshape(T)
    T = tf.tile(T, (1, 4, 4, 1))

    X = self.conv1(I)
    X = tf.nn.leaky_relu(X)

    X = self.conv2(X)
    X = self.batchnorm1(X)
    X = tf.nn.leaky_relu(X)
    
    X = self.conv3(X)
    X = self.batchnorm2(X)
    X = tf.nn.leaky_relu(X)
    
    X = self.conv4(X)
    X = self.batchnorm3(X)
    X = tf.nn.leaky_relu(X)
    
    X = self.conv5(X)
    X = self.batchnorm4(X)
    X = tf.nn.leaky_relu(X)
   
    X = self.conv6(X)
    X = self.batchnorm5(X)
    X = tf.nn.leaky_relu(X)
    
    X = self.conv7(X)
    X = self.batchnorm6(X)
    X = tf.nn.leaky_relu(X)
    
    X = self.conv8(X)
    X = self.batchnorm7(X)

    Y = self.conv9(X)
    Y = self.batchnorm8(Y)
    Y = tf.nn.leaky_relu(Y)

    Y = self.conv10(Y)
    Y = self.batchnorm9(Y)
    Y = tf.nn.leaky_relu(Y)

    Y = self.conv11(Y)
    Y = self.batchnorm10(Y)

    A = tf.keras.layers.Add()([X, Y])
    A = tf.nn.leaky_relu(A)

    merged_input = tf.keras.layers.concatenate([A, T])

    Z = self.conv12(merged_input)
    Z = self.batchnorm11(Z)
    Z = tf.nn.leaky_relu(Z)
    
    Z = self.conv13(Z)
    return tf.squeeze(Z)

# %%
class Stage2Model(tf.keras.Model):
  def __init__(self):
    super(Stage2Model, self).__init__()
    self.stage1_generator = Stage1Generator()
    self.stage1_generator.compile(loss = "mse", optimizer = "adam")
    self.stage1_generator.load_weights("./Text to Image/lr_model_checkpoints/stage1_generator_600.ckpt").expect_partial()
    
    self.stage2_generator = Stage2Generator()
    self.stage2_discriminator = Stage2Discriminator()
    self.stage2_generator.compile(loss = "mse", optimizer = "adam")
    self.stage2_generator.load_weights("./Text to Image/hr_model_checkpoints/stage2_generator_170.ckpt").expect_partial()
    self.stage2_discriminator.compile(loss = "mse", optimizer = "adam")
    self.stage2_discriminator.load_weights("./Text to Image/hr_model_checkpoints/stage2_discriminator_170.ckpt").expect_partial()
    
  def train(self, train_ds, batch_size = 64, num_epochs = 1200, z_dim = 100, stage1_generator_lr = 0.0001, stage1_discriminator_lr = 0.0001):
    generator_optimizer = tf.keras.optimizers.Adam(lr = stage1_generator_lr, beta_1 = 0.5, beta_2 = 0.999)
    discriminator_optimizer = tf.keras.optimizers.Adam(lr = stage1_discriminator_lr, beta_1 = 0.5, beta_2 = 0.999)
    
    for epoch in range(num_epochs):
      print("Epoch %d/%d:\n ["%(epoch + 1, num_epochs), end = "")
      start_time = time.time()
      if epoch % 100 == 0:
        K.set_value(generator_optimizer.learning_rate, generator_optimizer.learning_rate / 2)
        K.set_value(discriminator_optimizer.learning_rate, discriminator_optimizer.learning_rate / 2)
    
      generator_loss_log = []
      discriminator_loss_log = []
      steps_per_epoch = 125
      batch_iter = iter(train_ds)
      for i in range(steps_per_epoch):
        if i % 5 == 0:
          print("=", end = "")
        hr_image_batch, embedding_batch = next(batch_iter)
        z_noise = tf.random.normal((batch_size, z_dim))

        mismatched_images = tf.roll(hr_image_batch, shift = 1, axis = 0)

        real_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.9, maxval = 1.0)
        fake_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.0, maxval = 0.1)
        mismatched_labels = tf.random.uniform(shape = (batch_size, ), minval = 0.0, maxval = 0.1)

        with tf.GradientTape() as generator_tape, tf.GradientTape() as discriminator_tape:
          lr_fake_images, _ = self.stage1_generator([embedding_batch, z_noise])
          hr_fake_images, phi = self.stage2_generator([embedding_batch, lr_fake_images])
          real_logits = self.stage2_discriminator([hr_image_batch, embedding_batch])
          fake_logits = self.stage2_discriminator([hr_fake_images, embedding_batch])
          mismatched_logits = self.stage2_discriminator([mismatched_images, embedding_batch])
          
          l_sup = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(real_labels, fake_logits))
          l_klreg = KL_loss(tf.random.normal((phi.shape[0], phi.shape[1])), phi)
          generator_loss = l_sup + 2.0*l_klreg
          
          l_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(real_labels, real_logits))
          l_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(fake_labels, fake_logits))
          l_mismatched = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(mismatched_labels, mismatched_logits))
          discriminator_loss = 0.5*tf.add(l_real, 0.5*tf.add(l_fake, l_mismatched))
        
        generator_gradients = generator_tape.gradient(generator_loss, self.stage2_generator.trainable_variables)
        discriminator_gradients = discriminator_tape.gradient(discriminator_loss, self.stage2_discriminator.trainable_variables)
        
        generator_optimizer.apply_gradients(zip(generator_gradients, self.stage2_generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(discriminator_gradients, self.stage2_discriminator.trainable_variables))
        
        generator_loss_log.append(generator_loss)
        discriminator_loss_log.append(discriminator_loss)
        
      end_time = time.time()

      if epoch % 1 == 0:
        epoch_time = end_time - start_time
        template = "] - generator_loss: {:.4f} - discriminator_loss: {:.4f} - epoch_time: {:.2f} s"
        print(template.format(tf.reduce_mean(generator_loss_log), tf.reduce_mean(discriminator_loss_log), epoch_time))

      if (epoch + 1) % 10 == 0 or epoch == num_epochs - 1:
        save_path = "./Text to Image/hr_results/epoch_" + str(epoch + 1)
        temp_embeddings = None
        for _, embeddings in train_ds:
          temp_embeddings = embeddings.numpy()
          break
        if os.path.exists(save_path) == False:
          os.makedirs(save_path)
        temp_batch_size = 10
        temp_z_noise = tf.random.normal((temp_batch_size, z_dim))
        temp_embedding_batch = temp_embeddings[0:temp_batch_size]
        fake_images, _ = self.stage1_generator([temp_embedding_batch, temp_z_noise])
        for i, image in enumerate(fake_images):
          image = 127.5*image + 127.5
          image = image.numpy().astype('uint8')
          cv2.imwrite(save_path + "/gen_%d.png"%(i), image)
        self.stage2_generator.save_weights("./Text to Image/hr_model_checkpoints/stage2_generator_" + str(epoch + 1) + ".ckpt")
        self.stage2_discriminator.save_weights("./Text to Image/hr_model_checkpoints/stage2_discriminator_" + str(epoch + 1) + ".ckpt")

# %%
IMAGE_HEIGHT = 256
IMAGE_WIDTH = 256
dataset = dataset_generator(data_path + '/text2ImgData.pkl', BATCH_SIZE, training_data_generator)
stage2_model = Stage2Model()
stage2_model.train(dataset)

# %% [markdown]
# ## Visualization

# %%
def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j*h:j*h+h, i*w:i*w+w, :] = image
    return img

def imsave(images, size, path):
    # getting the pixel values between [0, 1] to save it
    return plt.imsave(path, merge(images, size)*0.5 + 0.5)

def save_images(images, size, image_path):
    return imsave(images, size, image_path)

# %%
def sample_generator(caption, batch_size):
    caption = np.asarray(caption)
    caption = caption.astype(np.int)
    dataset = tf.data.Dataset.from_tensor_slices(caption)
    dataset = dataset.batch(batch_size)
    return dataset

# %%
ni = int(np.ceil(np.sqrt(hparas['BATCH_SIZE'])))
sample_size = hparas['BATCH_SIZE']
sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
sample_sentence = ["the flower shown has yellow anther red pistil and bright red petals."] * int(sample_size/ni) + \
                  ["this flower has petals that are yellow, white and purple and has dark lines"] * int(sample_size/ni) + \
                  ["the petals on this flower are white with a yellow center"] * int(sample_size/ni) + \
                  ["this flower has a lot of small round pink petals."] * int(sample_size/ni) + \
                  ["this flower is orange in color, and has petals that are ruffled and rounded."] * int(sample_size/ni) + \
                  ["the flower has yellow petals and the center of it is brown."] * int(sample_size/ni) + \
                  ["this flower has petals that are blue and white."] * int(sample_size/ni) +\
                  ["these white flowers have petals that start off white in color and end in a white towards the tips."] * int(sample_size/ni)

for i, sent in enumerate(sample_sentence):
    sample_sentence[i] = sent2IdList(sent)
sample_sentence = sample_generator(sample_sentence, hparas['BATCH_SIZE'])
# Out:
# c:\Users\user\anaconda3\envs\tf_env\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Training

# %%
if not os.path.exists('samples/demo'):
    os.makedirs('samples/demo')

# %%
def train(dataset, epochs):
    # hidden state of RNN
    hidden = text_encoder.initialize_hidden_state()
    steps_per_epoch = int(hparas['N_SAMPLE']/hparas['BATCH_SIZE'])
    
    for epoch in range(hparas['N_EPOCH']):
        g_total_loss = 0
        d_total_loss = 0
        start = time.time()
        
        for image, caption in dataset:
            g_loss, d_loss = train_step(image, caption, hidden)
            g_total_loss += g_loss
            d_total_loss += d_loss
            
        time_tuple = time.localtime()
        time_string = time.strftime("%m/%d/%Y, %H:%M:%S", time_tuple)
            
        print("Epoch {}, gen_loss: {:.4f}, disc_loss: {:.4f}".format(epoch+1,
                                                                     g_total_loss/steps_per_epoch,
                                                                     d_total_loss/steps_per_epoch))
        print('Time for epoch {} is {:.4f} sec'.format(epoch+1, time.time()-start))
        
        # save the model
        if (epoch + 1) % 10 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        
        # visualization
        if (epoch + 1) % hparas['PRINT_FREQ'] == 0:
            for caption in sample_sentence:
                fake_image = test_step(caption, sample_seed, hidden)
            save_images(fake_image, [ni, ni], 'samples/demo/train_{:02d}.jpg'.format(epoch))

# %%
train(dataset, hparas['N_EPOCH'])
# Out:
# Epoch 1, gen_loss: 0.4707, disc_loss: 1.0885
# Time for epoch 1 is 18.1674 sec
# Epoch 2, gen_loss: 0.5574, disc_loss: 0.9490
# Time for epoch 2 is 16.9456 sec
# Epoch 3, gen_loss: 0.7402, disc_loss: 0.7629
# Time for epoch 3 is 17.3516 sec
# Epoch 4, gen_loss: 1.3450, disc_loss: 0.3981
# Time for epoch 4 is 18.2550 sec
# Epoch 5, gen_loss: 2.0509, disc_loss: 0.1843
# Time for epoch 5 is 17.4844 sec
# Epoch 6, gen_loss: 1.8685, disc_loss: 0.2176
# Time for epoch 6 is 16.4693 sec
# Epoch 7, gen_loss: 2.4892, disc_loss: 0.1314
# Time for epoch 7 is 17.3523 sec
# Epoch 8, gen_loss: 2.6612, disc_loss: 0.1400
# Time for epoch 8 is 15.7512 sec
# Epoch 9, gen_loss: 2.9363, disc_loss: 0.1452
# Time for epoch 9 is 16.0982 sec
# Epoch 10, gen_loss: 3.5661, disc_loss: 0.1384
# Time for epoch 10 is 15.2816 sec

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Testing dataset

# %%
def testing_data_generator(caption, index):
    caption = tf.cast(caption, tf.float32)
    return caption, index

def testing_dataset_generator(batch_size, data_generator):
    data = pd.read_pickle('./2024-datalab-cup3-reverse-image-caption/dataset/testData.pkl')
    captions = data['Captions'].values
    caption = []
    for i in range(len(captions)):
        caption.append(captions[i])
    caption = np.asarray(caption)
    caption = caption.astype(np.int)
    index = data['ID'].values
    index = np.asarray(index)
    
    dataset = tf.data.Dataset.from_tensor_slices((caption, index))
    dataset = dataset.map(data_generator, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.repeat().batch(batch_size)
    
    return dataset

# %%
testing_dataset = testing_dataset_generator(hparas['BATCH_SIZE'], testing_data_generator)
# Out:
# c:\Users\user\anaconda3\envs\tf_env\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == "":

# %%
data = pd.read_pickle('./2024-datalab-cup3-reverse-image-caption/dataset/testData.pkl')
captions = data['Captions'].values

NUM_TEST = len(captions)
EPOCH_TEST = int(NUM_TEST / hparas['BATCH_SIZE'])

# %% [markdown]
# ### Inference

# %%
if not os.path.exists('./inference/demo'):
    os.makedirs('./inference/demo')

# %%
def inference(dataset):
    hidden = text_encoder.initialize_hidden_state()
    sample_size = hparas['BATCH_SIZE']
    sample_seed = np.random.normal(loc=0.0, scale=1.0, size=(sample_size, hparas['Z_DIM'])).astype(np.float32)
    
    step = 0
    start = time.time()
    for captions, idx in dataset:
        if step > EPOCH_TEST:
            break
        
        fake_image = test_step(captions, sample_seed, hidden)
        step += 1
        for i in range(hparas['BATCH_SIZE']):
            plt.imsave('./inference/demo/inference_{:04d}.jpg'.format(idx[i]), fake_image[i].numpy()*0.5 + 0.5)
            
    print('Time for inference is {:.4f} sec'.format(time.time()-start))

# %%
checkpoint.restore(checkpoint_dir + '/ckpt-1')

# %%
inference(testing_dataset)
# Out:
# Time for inference is 3.0621 sec

# %% [markdown]
# ## Inception score

# %%
from numba import cuda

cuda.get_current_device().reset()

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
score_file = './score.csv'
if os.path.exists(score_file):
    os.remove(score_file)

# %%
# %cd testing
# !python inception_score.py ../inference/demo/ ../score.csv 39
# %cd ..
# Out:
# c:\Users\user\OneDrive - NTHU\桌面\DL\Comp3\testing
# 1 Physical GPUs, 1 Logical GPUs
# ['C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0023.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0041.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0057.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0058.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0059.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0068.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0072.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0078.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0081.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0089.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0120.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0132.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0144.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0164.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0192.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0194.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0198.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0205.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0207.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0210.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0211.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0216.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0224.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0230.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0233.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0253.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0261.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0264.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0267.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0269.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0284.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0289.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0292.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0301.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0309.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0310.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0312.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0319.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0324.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0327.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0343.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0372.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0380.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0386.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0395.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0402.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0404.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0413.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0417.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0427.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0460.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0465.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0471.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0480.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0489.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0499.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0504.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0510.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0513.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0518.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0537.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0545.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0565.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0579.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0586.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0600.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0604.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0611.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0622.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0628.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0630.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0633.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0636.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0643.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0645.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0664.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0677.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0692.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0713.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0725.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0733.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0753.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0759.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0786.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0795.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0797.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0798.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0806.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0821.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0827.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0828.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0841.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0846.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0851.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0856.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0859.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0868.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0876.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0878.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0912.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0921.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0929.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0933.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0945.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0951.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0956.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0963.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0974.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_0984.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1008.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1014.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1015.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1050.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1052.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1054.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1058.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1065.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1075.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1106.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1113.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1114.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1116.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1121.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1133.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1134.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1138.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1148.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1151.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1156.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1169.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1177.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1179.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1186.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1195.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1209.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1238.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1241.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1246.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1260.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1274.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1277.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1295.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1296.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1317.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1325.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1335.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1338.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1347.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1353.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1355.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1373.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1375.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1378.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1385.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1392.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1399.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1404.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1414.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1429.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1431.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1434.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1435.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1454.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1460.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1469.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1480.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1483.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1492.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1494.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1499.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1522.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1547.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1562.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1565.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1567.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1568.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1569.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1570.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1582.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1585.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1593.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1595.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1603.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1604.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1607.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1610.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1626.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1629.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1640.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1643.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1654.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1656.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1660.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1664.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1668.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1672.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1681.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1683.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1685.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1688.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1701.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1703.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1714.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1716.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1717.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1725.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1726.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1753.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1779.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1804.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1808.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1831.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1841.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1863.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1896.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1899.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1904.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1914.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1917.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1921.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1931.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1954.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1956.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1984.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_1999.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2010.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2011.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2014.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2028.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2036.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2037.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2082.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2090.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2098.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2099.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2102.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2106.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2111.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2130.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2132.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2135.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2136.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2147.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2149.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2168.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2169.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2196.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2208.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2216.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2224.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2225.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2237.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2258.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2276.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2309.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2320.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2323.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2335.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2347.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2356.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2367.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2370.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2374.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2394.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2406.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2409.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2423.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2424.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2427.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2429.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2431.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2481.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2486.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2500.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2501.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2510.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2530.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2540.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2542.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2550.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2554.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2557.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2569.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2577.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2611.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2621.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2639.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2648.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2668.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2686.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2687.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2705.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2723.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2726.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2731.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2737.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2753.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2765.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2781.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2786.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2822.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2839.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2841.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2848.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2854.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2858.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2867.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2872.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2880.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2885.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2891.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2897.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2901.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2904.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2905.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2922.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2941.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2943.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2947.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2951.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2962.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2968.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2969.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2970.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_2992.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3010.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3013.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3015.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3016.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3024.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3026.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3049.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3051.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3071.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3093.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3097.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3145.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3181.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3197.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3199.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3200.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3225.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3234.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3237.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3243.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3251.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3252.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3255.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3270.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3284.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3296.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3322.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3323.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3327.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3336.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3353.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3412.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3422.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3426.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3427.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3448.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3462.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3464.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3465.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3472.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3476.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3482.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3492.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3499.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3512.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3515.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3531.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3535.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3561.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3565.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3579.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3583.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3594.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3602.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3625.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3639.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3644.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3646.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3654.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3660.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3688.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3692.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3707.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3719.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3724.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3729.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3731.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3734.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3735.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3743.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3750.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3772.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3774.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3786.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3788.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3800.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3802.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3808.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3836.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3837.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3842.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3860.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3861.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3865.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3870.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3871.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3878.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3879.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3883.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3885.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3890.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3891.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3893.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3897.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3899.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3927.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3936.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3940.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3962.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3965.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3970.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3978.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3985.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3989.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3992.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_3998.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4004.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4019.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4053.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4081.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4094.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4098.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4110.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4136.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4151.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4154.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4155.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4162.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4169.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4176.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4215.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4217.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4222.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4244.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4262.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4264.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4271.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4274.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4276.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4280.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4282.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4306.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4321.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4328.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4329.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4342.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4347.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4358.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4362.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4371.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4397.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4401.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4415.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4425.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4430.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4446.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4448.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4454.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4467.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4483.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4488.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4496.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4511.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4516.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4517.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4522.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4527.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4530.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4566.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4590.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4591.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4621.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4639.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4653.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4656.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4683.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4691.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4703.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4706.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4715.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4734.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4749.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4753.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4760.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4776.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4778.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4781.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4782.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4815.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4816.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4819.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4841.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4847.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4852.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4868.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4879.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4886.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4889.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4894.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4902.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4915.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4933.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4965.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4972.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4976.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4978.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4980.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4989.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4991.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_4996.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5043.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5067.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5107.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5108.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5133.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5147.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5148.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5175.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5177.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5181.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5184.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5187.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5190.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5198.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5260.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5266.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5281.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5311.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_5313.jpg'
# ...
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6359.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6362.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6381.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6406.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6409.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6410.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6413.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6415.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6416.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6434.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6447.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6450.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6452.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6479.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6488.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6499.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6505.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6515.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6519.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6529.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6530.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6536.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6546.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6569.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6571.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6576.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6579.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6584.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6606.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6623.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6647.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6662.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6670.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6676.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6679.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6686.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6710.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6719.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6720.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6726.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6735.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6740.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6746.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6759.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6762.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6765.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6784.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6793.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6804.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6813.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6818.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6843.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6845.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6859.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6874.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6875.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6879.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6890.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6901.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6917.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6926.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6936.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6960.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6964.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6982.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6988.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_6992.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7031.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7044.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7049.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7061.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7066.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7072.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7079.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7127.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7137.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7148.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7155.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7160.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7175.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7184.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7190.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7192.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7203.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7208.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7219.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7222.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7225.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7227.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7271.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7280.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7284.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7291.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7300.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7307.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7333.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7347.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7349.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7352.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7353.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7370.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7374.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7383.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7388.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7394.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7395.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7399.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7400.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7413.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7414.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7427.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7431.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7447.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7456.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7461.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7462.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7466.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7497.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7508.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7519.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7520.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7527.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7528.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7547.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7571.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7579.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7589.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7590.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7596.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7627.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7640.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7647.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7658.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7659.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7679.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7686.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7714.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7727.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7729.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7754.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7761.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7792.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7793.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7797.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7822.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7842.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7863.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7880.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7903.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7912.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7933.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7936.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7938.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7944.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7982.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7986.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7993.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_7996.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8000.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8012.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8014.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8026.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8042.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8050.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8056.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8061.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8066.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8073.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8076.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8083.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8090.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8094.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8101.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8126.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8134.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8136.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8157.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8164.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8166.jpg'
#  'C:\\Users\\user\\OneDrive - NTHU\\桌面\\DL\\Comp3\\inference\\demo\\inference_8189.jpg']
# --------------Evaluation Success-----------------
# c:\Users\user\OneDrive - NTHU\桌面\DL\Comp3

# %%
import os
import pandas as pd
import numpy as np

if os.path.exists(score_file):
    df_score = pd.read_csv(score_file)
    mean_score = np.mean(df_score['score'].values)
    print(f'Mean Score: {mean_score:f}')
else:
    print('Evaluation Failed!')
# Out:
# Mean Score: 1.035121
